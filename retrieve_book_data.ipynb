# %%
import requests
from bs4 import BeautifulSoup
import time
import json
from typing import Dict, List, Optional
import re
from datetime import datetime
import csv
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

class BookDataCollector:
    def __init__(self):
        self.goodreads_base_url = "https://www.goodreads.com"
        self.openlibrary_base_url = "https://openlibrary.org"
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

    def clean_title(self, title: str) -> str:
        """Remove series information from title for better search results"""
        # Remove series information in parentheses
        cleaned = re.sub("[\(\[].*?[\)\]]", "", title)
        # Remove extra spaces
        cleaned = ' '.join(cleaned.split())
        return cleaned.strip()

    def scrape_goodreads_decade_list(self, list_url: str, max_books: int = 100) -> List[Dict]:
        """Scrape books from a Goodreads list page"""
        books = []
        page = 1

        while len(books) < max_books:
            try:
                # Construct URL with pagination
                page_url = f"{list_url}?page={page}"
                response = requests.get(page_url, headers=self.headers)
                response.raise_for_status()

                soup = BeautifulSoup(response.content, 'html.parser')

                # Find all book entries on the page
                book_entries = soup.find_all('tr', itemtype='http://schema.org/Book')

                if not book_entries:
                    break

                for entry in book_entries:
                    if len(books) >= max_books:
                        break

                    book_data = self.extract_book_info(entry)
                    if book_data:
                        books.append(book_data)

                page += 1
                time.sleep(1)  # Be respectful to the server

            except Exception as e:
                print(f"Error scraping page {page}: {e}")
                break

        return books[:max_books]

    def extract_book_info(self, book_entry) -> Optional[Dict]:
        """Extract book information from a Goodreads list entry"""
        try:
            # Get title
            title_elem = book_entry.find('a', class_='bookTitle')
            full_title = title_elem.find('span').text.strip() if title_elem else None

            # Get author
            author_elem = book_entry.find('a', class_='authorName')
            author = author_elem.find('span').text.strip() if author_elem else None

            # Get Goodreads URL
            book_url = self.goodreads_base_url + title_elem['href'] if title_elem else None

            # Get rating
            rating_elem = book_entry.find('span', class_='minirating')
            rating_text = rating_elem.text.strip() if rating_elem else ""
            rating_match = re.search(r'(\d+\.\d+)', rating_text)
            rating = float(rating_match.group(1)) if rating_match else None

            # Get number of ratings
            ratings_count_match = re.search(r'([\d,]+)\s+ratings', rating_text)
            ratings_count = int(ratings_count_match.group(1).replace(',', '')) if ratings_count_match else None

            return {
                'title': full_title,
                'clean_title': self.clean_title(full_title) if full_title else None,
                'author': author,
                'goodreads_url': book_url,
                'rating': rating,
                'ratings_count': ratings_count
            }

        except Exception as e:
            print(f"Error extracting book info: {e}")
            return None

    def search_openlibrary(self, title: str, author: str, clean_title: str) -> Optional[Dict]:
        """Search for a book on Open Library and get its metadata"""
        try:
            # Try with clean title first
            search_queries = [
                f"{clean_title} {author}",
                clean_title]

            # If the clean title is different from the original title, try that as well
            if clean_title != title:
                search_queries.append(f"{title} {author}")
                search_queries.append(title)

            # If title starts with "the," add query with "the" removed
            if title.lower().startswith("the "):
                search_queries.append(f"{clean_title[4:]} {author}")
                search_queries.append(f"{clean_title[4:]}")
                if clean_title[4:] != title[4:]:
                    search_queries.append(f"{title[4:]} {author}")
                    search_queries.append(f"{title[4:]}")

            for query in search_queries:
                search_url = f"{self.openlibrary_base_url}/search.json"

                params = {
                    'q': query.strip(),
                    'limit': 10,
                    'language': 'eng',
                    # 'has_fulltext': 'true',  # Prefer editions with full text
                    # 'fields': '*,number_of_pages,number_of_pages_median'  # Request all fields
                }

                response = requests.get(search_url, params=params)
                response.raise_for_status()

                data = response.json()

                if data.get('docs'):

                    # Try to find the best match
                    for doc in data['docs']:
                        # Check if author matches
                        doc_authors = doc.get('author_name', [])
                        if any(self.fuzzy_match(author, doc_author) for doc_author in doc_authors):
                            result = self.get_book_details(doc)
                            if result:
                              # print("returning result from matching author name")
                              return result

                    # If no good author match, try title match
                    for doc in data['docs']:
                        doc_title = doc.get('title', '').lower()
                        if self.fuzzy_match(clean_title.lower(), doc_title):
                            result = self.get_book_details(doc)
                        elif clean_title.lower().startswith("the ") and self.fuzzy_match(clean_title[4:].lower(), doc_title):
                            result = self.get_book_details(doc)
                        if result:
                          # print("returning result from matching title name")
                          return result

                time.sleep(0.3)  # Small delay between searches

            return None

        except Exception as e:
            print(f"Error searching Open Library for '{title}': {e}")
            return None


    def fuzzy_match(self, str1: str, str2: str, threshold: float = 0.8) -> bool:
        """Simple fuzzy string matching"""
        str1_lower = str1.lower()
        str2_lower = str2.lower()

        # Exact match
        if str1_lower == str2_lower:
            return True

        # One contains the other
        if str1_lower in str2_lower or str2_lower in str1_lower:
            return True

        # Check if most words match
        words1 = set(str1_lower.split())
        words2 = set(str2_lower.split())

        if not words1 or not words2:
            return False

        intersection = words1.intersection(words2)
        union = words1.union(words2)

        return len(intersection) / len(union) >= threshold

    def get_book_details(self, book_doc: Dict) -> Dict:
        """Extract detailed information from Open Library book document"""
        details = {
            'olid': book_doc.get('key', ''),
            'description': None,
            'first_publish_year': book_doc.get('first_publish_year'),
            'number_of_pages': None,
            'subjects': book_doc.get('subject', [])[:10],  # Top 10 subjects
            'isbn': book_doc.get('isbn', [])[:1],  # First ISBN
            'language': book_doc.get('language', [])[:1]
        }

        # Get work details for description
        if book_doc.get('key'):
            work_details = self.get_work_details(details['olid'])
            description = None
            if isinstance(work_details.get('description'), dict):
                description = work_details['description'].get('value', '')
            elif isinstance(work_details.get('description'), str):
                description = work_details['description']
            details['description'] = description

        return details

    def get_work_details(self, work_key: str) -> Optional[Dict]:
        """Get details for a work"""
        try:
            url = f"{self.openlibrary_base_url}{work_key}.json"
            response = requests.get(url)
            response.raise_for_status()

            data = response.json()

            return data

        except Exception as e:
            return None

    def collect_decade_data(self, decade_start: int, list_url: str, max_books: int = 100) -> List[Dict]:
        """Collect data for all books in a decade"""
        print(f"\nCollecting data for {decade_start}s...")

        # Scrape Goodreads list
        books = self.scrape_goodreads_decade_list(list_url, max_books)
        print(f"Found {len(books)} books on Goodreads")

        # Enrich with Open Library data
        enriched_books = []
        for i, book in enumerate(books, 1):
            print(f"Processing {i}/{len(books)}: {book['title']} by {book['author']}")

            num_tries = 0

            while num_tries < 4:

              # Search Open Library
              ol_data = self.search_openlibrary(
                  book['title'],
                  book['author'],
                  book['clean_title']
              )

              num_tries += 1

              # Combine data
              enriched_book = book.copy()
              enriched_book['decade'] = decade_start

              if ol_data and ol_data.get('description'):
                  break


            if ol_data:
                enriched_book.update(ol_data)
                print(f"  ✓ Found in Open Library")
                if ol_data.get('description'):
                    print(f"    - Has description")
                if ol_data.get('number_of_pages'):
                    print(f"    - Has page count: {ol_data['number_of_pages']}")
            else:
                print(f"  ✗ Not found in Open Library")

            # Final status
            # if enriched_book.get('description') and enriched_book.get('number_of_pages'):
            #     print(f"  ✓ Complete: Has both description and page count")
            # elif enriched_book.get('description'):
            #     print(f"  ⚠ Partial: Has description but no page count")
            # elif enriched_book.get('number_of_pages'):
            #     print(f"  ⚠ Partial: Has page count but no description")
            # else:
            #     print(f"  ⚠ Missing: No description or page count found")

            if enriched_book.get('description'):
                print(f"  ✓ Has description")
            else:
                print(f"  ⚠ Missing description")

            enriched_books.append(enriched_book)

            # Rate limiting
            time.sleep(0.5)

        # Summary
        books_with_description = sum(1 for book in enriched_books if book.get('description'))
        # books_with_pages = sum(1 for book in enriched_books if book.get('number_of_pages'))
        books_complete = sum(1 for book in enriched_books if book.get('description') and book.get('number_of_pages'))

        print(f"\nSummary for {decade_start}s:")
        print(f"  - Books with descriptions: {books_with_description}/{len(enriched_books)}")
        # print(f"  - Books with page counts: {books_with_pages}/{len(enriched_books)}")
        # print(f"  - Books with both: {books_complete}/{len(enriched_books)}")

        return enriched_books

    def save_to_csv(self, books: List[Dict], filename: str, drive_folder: str = 'MyDrive/new_book_data'):
        """Save book data to CSV file in Google Drive"""
        if not books:
            return

        # Create the full path in Google Drive
        drive_path = f'/content/drive/{drive_folder}'

        # Create directory if it doesn't exist
        os.makedirs(drive_path, exist_ok=True)

        # Full file path
        filepath = os.path.join(drive_path, filename)

        # Define CSV columns
        fieldnames = [
            'decade', 'title', 'clean_title', 'author', 'rating', 'ratings_count',
            'first_publish_year', 'number_of_pages', 'description',
            'subjects', 'isbn', 'language', 'goodreads_url', 'olid',
        ]

        with open(filepath, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

            for book in books:
                # Convert lists to strings for CSV
                row = book.copy()
                for key in ['subjects', 'isbn', 'language']:
                    if key in row and isinstance(row[key], list):
                        row[key] = '; '.join(str(item) for item in row[key])

                writer.writerow({k: row.get(k, '') for k in fieldnames})

        print(f"✓ CSV saved to Google Drive: {filepath}")

    def save_to_json(self, books: List[Dict], filename: str, drive_folder: str = 'MyDrive/book_data'):
        """Save book data to JSON file in Google Drive"""
        # Create the full path in Google Drive
        drive_path = f'/content/drive/{drive_folder}'

        # Create directory if it doesn't exist
        os.makedirs(drive_path, exist_ok=True)

        # Full file path
        filepath = os.path.join(drive_path, filename)

        with open(filepath, 'w', encoding='utf-8') as f:
            json.dump(books, f, indent=2, ensure_ascii=False)

        print(f"✓ JSON saved to Google Drive: {filepath}")
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\('
# <>:26: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-1213824136.py:26: SyntaxWarning: invalid escape sequence '\('
#   cleaned = re.sub("[\(\[].*?[\)\]]", "", title)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
collector = BookDataCollector()

# Define decade URLs (you'll need to update these with actual URLs)
# Define decade URLs
decade_urls = {
    1900: "https://www.goodreads.com/list/show/38",
    1910: "https://www.goodreads.com/list/show/93",
    1920: "https://www.goodreads.com/list/show/39",
    1930: "https://www.goodreads.com/list/show/85",
    1940: "https://www.goodreads.com/list/show/23",
    1950: "https://www.goodreads.com/list/show/22",
    1960: "https://www.goodreads.com/list/show/18",
    1970: "https://www.goodreads.com/list/show/21",
    1980: "https://www.goodreads.com/list/show/9",
    1990: "https://www.goodreads.com/list/show/17",
    2000: "https://www.goodreads.com/list/show/5",
    2010: "https://www.goodreads.com/list/show/4093",
    2020: "https://www.goodreads.com/list/show/143500"
}

for decade_start in decade_urls.keys():
    all_books = []

    books = collector.collect_decade_data(
        decade_start=decade_start,
        list_url=decade_urls[decade_start],
        max_books=100
    )

    all_books.extend(books)

    # Save data
    # timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    # collector.save_to_csv(all_books, f"books_data_{timestamp}.csv")
    collector.save_to_csv(all_books, f"books_data_{decade_start}.csv")
    # collector.save_to_json(all_books, f"books_data_{timestamp}.json")

    print(f"\nData collection complete! Collected {len(all_books)} books.")

    # Print statistics
    books_with_desc = sum(1 for book in all_books if book.get('description'))
    # books_with_pages = sum(1 for book in all_books if book.get('number_of_pages'))
    # books_complete = sum(1 for book in all_books if book.get('description') and book.get('number_of_pages'))

    print(f"\nOverall Statistics:")
    print(f"- Books with descriptions: {books_with_desc}/{len(all_books)} ({books_with_desc/len(all_books)*100:.1f}%)")
    # print(f"- Books with page counts: {books_with_pages}/{len(all_books)} ({books_with_pages/len(all_books)*100:.1f}%)")
    # print(f"- Books with both: {books_complete}/{len(all_books)} ({books_complete/len(all_books)*100:.1f}%)")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing 74/100: The Unabridged Devil's Dictionary by Ambrose Bierce
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 75/100: Arsène Lupin, Gentleman-Thief by Maurice Leblanc
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 76/100: Beneath the Wheel by Hermann Hesse
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 77/100: The Diaries of Adam and Eve by Mark Twain
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 78/100: The Tale of Mrs. Tiggy-Winkle (World of Beatrix Potter, #6) by Beatrix Potter
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 79/100: The Life and Adventures of Santa Claus by L. Frank Baum
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 80/100: Tonio Kröger / Mario und der Zauberer by Thomas Mann
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 81/100: Green Mansions by William Henry Hudson
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 82/100: The Tailor of Gloucester (World of Beatrix Potter, #3) by Beatrix Potter
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 83/100: The Playboy of the Western World and Other Plays by J.M. Synge
# Error searching Open Library for 'The Playboy of the Western World and Other Plays': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Playboy of the Western World and Other Plays': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Playboy of the Western World and Other Plays': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Playboy of the Western World and Other Plays': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 84/100: The Psychopathology of Everyday Life by Sigmund Freud
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 85/100: The Tale of Jemima Puddle-Duck (World of Beatrix Potter, #12) by Beatrix Potter
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 86/100: Mother by Maxim Gorky
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 87/100: Ghost Stories of an Antiquary by M.R. James
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 88/100: Lieutenant Gustl by Arthur Schnitzler
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 89/100: The Education of Henry Adams by Henry Adams
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 90/100: The Magician by W. Somerset Maugham
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 91/100: I Am a Cat by Natsume Sōseki
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 92/100: The Tale of the Flopsy Bunnies (World of Beatrix Potter, #14) by Beatrix Potter
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 93/100: The Book of Tea by Kakuzō Okakura
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 94/100: Kwaidan: Stories and Studies of Strange Things by Lafcadio Hearn
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 95/100: Three Lives by Gertrude Stein
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 96/100: The Story of a Fierce Bad Rabbit (World of Beatrix Potter, #9) by Beatrix Potter
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 97/100: Freckles (Limberlost, #1) by Gene Stratton-Porter
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 98/100: Raffles: Further Adventures of the Amateur Cracksman by E.W. Hornung
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 89/100: The Home and the World by Rabindranath Tagore
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 90/100: Old Mother West Wind (Old Mother West Wind, #1) by Thornton W. Burgess
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 91/100: Pollyanna Grows Up (Pollyanna #2) by Eleanor H. Porter
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 92/100: Lad: A Dog (Lad, #1) by Albert Payson Terhune
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 93/100: Greenmantle (Richard Hannay #2) by John Buchan
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 94/100: Fantômas (Fantômas, #1) by Marcel Allain
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 95/100: South Sea Tales by Jack London
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 96/100: Death in Venice by Thomas Mann
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 97/100: The Night Land by William Hope Hodgson
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 98/100: La Symphonie pastorale by André Gide
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 99/100: The Complete Father Brown Stories by G.K. Chesterton
# Error searching Open Library for 'The Complete Father Brown Stories': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Complete Father Brown Stories': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Complete Father Brown Stories': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Complete Father Brown Stories': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 100/100: Tarzan and the Jewels of Opar (Tarzan, #5) by Edgar Rice Burroughs
#   ✗ Not found in Open Library
#   ⚠ Missing description
#
# Summary for 1910s:
#   - Books with descriptions: 79/100
# ✓ CSV saved to Google Drive: /content/drive/MyDrive/new_book_data/books_data_1910.csv
#
# Data collection complete! Collected 100 books.
#
# Overall Statistics:
# - Books with descriptions: 79/100 (79.0%)
#
# Collecting data for 1920s...
# Found 100 books on Goodreads
# Processing 1/100: The Great Gatsby by F. Scott Fitzgerald
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 2/100: Winnie-the-Pooh (Winnie-the-Pooh, #1) by A.A. Milne
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 3/100: All Quiet on the Western Front by Erich Maria Remarque
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 4/100: The Sun Also Rises by Ernest Hemingway
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 5/100: Siddhartha by Hermann Hesse
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 6/100: The Sound and the Fury by William Faulkner
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 7/100: A Farewell to Arms by Ernest Hemingway
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 8/100: Mrs. Dalloway by Virginia Woolf
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 9/100: The Age of Innocence by Edith Wharton
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 10/100: The Trial by Franz Kafka
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 11/100: To the Lighthouse by Virginia Woolf
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 12/100: Steppenwolf by Hermann Hesse
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 13/100: Ulysses by James Joyce
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 14/100: The Murder of Roger Ackroyd (Hercule Poirot, #4) by Agatha Christie
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 15/100: A Passage to India by E.M. Forster
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 16/100: The Velveteen Rabbit by Margery Williams Bianco
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 17/100: A Room of One’s Own by Virginia Woolf
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 18/100: The Mysterious Affair at Styles (Hercule Poirot, #1) by Agatha Christie
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 19/100: The Waste Land and Other Poems by T.S. Eliot
# Error searching Open Library for 'The Waste Land and Other Poems': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Waste Land and Other Poems': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Waste Land and Other Poems': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Waste Land and Other Poems': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 20/100: Lady Chatterley’s Lover by D.H. Lawrence
# Error searching Open Library for 'Lady Chatterley’s Lover': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'Lady Chatterley’s Lover': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 21/100: The Prophet by Kahlil Gibran
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 22/100: The Magic Mountain by Thomas Mann
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 23/100: Orlando by Virginia Woolf
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 24/100: This Side of Paradise by F. Scott Fitzgerald
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 25/100: Death Comes for the Archbishop by Willa Cather
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 26/100: We by Yevgeny Zamyatin
# Error searching Open Library for 'We': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'We': 422 Client Error: Unprocessable Entity for url: https://openlibrary.org/search.json?q=We&limit=10&language=eng
# Error searching Open Library for 'We': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'We': 422 Client Error: Unprocessable Entity for url: https://openlibrary.org/search.json?q=We&limit=10&language=eng
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 76/100: U.S.A.: The 42nd Parallel / 1919 / The Big Money by John Dos Passos
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 77/100: Ballet Shoes (Shoes, #1) by Noel Streatfeild
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 78/100: Appointment with Death (Hercule Poirot, #19) by Agatha Christie
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 79/100: Murder in the Cathedral by T.S. Eliot
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 80/100: Tortilla Flat by John Steinbeck
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 81/100: Murder Must Advertise  (Lord Peter Wimsey, #10) by Dorothy L. Sayers
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 82/100: Scoop by Evelyn Waugh
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 83/100: The Wall by Jean-Paul Sartre
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 84/100: Hercule Poirot's Christmas (Hercule Poirot, #20) by Agatha Christie
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 85/100: Goodbye, Mr. Chips by James Hilton
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 86/100: The Death of the Heart by Elizabeth Bowen
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 87/100: Miss Pettigrew Lives for a Day by Winifred Watson
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 88/100: Death on the Installment Plan by Louis-Ferdinand Céline
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 89/100: The Man Without Qualities by Robert Musil
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 90/100: Jamaica Inn by Daphne du Maurier
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 91/100: A Universal History of Iniquity by Jorge Luis Borges
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 92/100: My Life and Hard Times by James Thurber
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 93/100: Goodbye to Berlin by Christopher Isherwood
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 94/100: The Street of Crocodiles by Bruno Schulz
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 95/100: The Five Red Herrings (Lord Peter Wimsey, #7) by Dorothy L. Sayers
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 96/100: Have His Carcase  (Lord Peter Wimsey, #7) by Dorothy L. Sayers
# ...
#     - Has description
#   ✓ Has description
# Processing 89/100: Queen of Shadows (Throne of Glass, #4) by Sarah J. Maas
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 90/100: Bring Up the Bodies (Thomas Cromwell, #2) by Hilary Mantel
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 91/100: Crescendo (Hush, Hush, #2) by Becca Fitzpatrick
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 92/100: The Passage (The Passage, #1) by Justin Cronin
# Error searching Open Library for 'The Passage (The Passage, #1)': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'The Passage (The Passage, #1)': cannot access local variable 'result' where it is not associated with a value
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 93/100: Bloodlines (Bloodlines, #1) by Richelle Mead
# Error searching Open Library for 'Bloodlines (Bloodlines, #1)': cannot access local variable 'result' where it is not associated with a value
# Error searching Open Library for 'Bloodlines (Bloodlines, #1)': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 94/100: The Iron King (The Iron Fey, #1) by Julie Kagawa
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 95/100: Go the F**k to Sleep by Adam Mansbach
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 96/100: Silence (Hush, Hush, #3) by Becca Fitzpatrick
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 97/100: State of Wonder by Ann Patchett
# Error searching Open Library for 'State of Wonder': cannot access local variable 'result' where it is not associated with a value
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 98/100: The Art of Fielding by Chad Harbach
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 99/100: Winter of the World (The Century Trilogy #2) by Ken Follett
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 100/100: Pandemonium (Delirium, #2) by Lauren Oliver
#   ✓ Found in Open Library
#   ⚠ Missing description
#
# Summary for 2010s:
#   - Books with descriptions: 92/100
# ✓ CSV saved to Google Drive: /content/drive/MyDrive/new_book_data/books_data_2010.csv
#
# Data collection complete! Collected 100 books.
#
# Overall Statistics:
# - Books with descriptions: 92/100 (92.0%)
#
# Collecting data for 2020s...
# Found 100 books on Goodreads
# Processing 1/100: The Invisible Life of Addie LaRue by V.E. Schwab
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 2/100: Project Hail Mary by Andy Weir
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 3/100: The House in the Cerulean Sea (Cerulean Chronicles, #1) by T.J. Klune
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 4/100: The Midnight Library by Matt Haig
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 5/100: I’m Glad My Mom Died by Jennette McCurdy
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 59/100: The Housemaid (The Housemaid, #1) by Freida McFadden
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 60/100: The Maid (Molly the Maid, #1) by Nita Prose
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 61/100: The Anthropocene Reviewed: Essays on a Human-Centered Planet by John Green
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 62/100: The Rose Code by Kate Quinn
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 63/100: James by Percival Everett
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 64/100: A Promised Land by Barack Obama
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 65/100: Rule of Wolves (King of Scars, #2) by Leigh Bardugo
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 66/100: The Glass Hotel by Emily St. John Mandel
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 67/100: Greenlights by Matthew McConaughey
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 68/100: Firekeeper’s Daughter (Firekeeper's Daughter, #1) by Angeline Boulley
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 69/100: Hood Feminism: Notes from the Women That a Movement Forgot by Mikki Kendall
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 70/100: Shuggie Bain by Douglas   Stuart
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 71/100: Cemetery Boys (Cemetery Boys, #1) by Aiden Thomas
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 72/100: Untamed by Glennon Doyle
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 73/100: These Violent Delights (These Violent Delights, #1) by Chloe Gong
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 74/100: Transcendent Kingdom by Yaa Gyasi
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 75/100: Legends & Lattes (Legends & Lattes, #1) by Travis Baldree
# Error searching Open Library for 'Legends & Lattes (Legends & Lattes, #1)': cannot access local variable 'result' where it is not associated with a value
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 76/100: The Push by Ashley Audrain
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 77/100: Writers & Lovers by Lily King
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 78/100: The Sun Down Motel by Simone St. James
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 79/100: The Book of Lost Names by Kristin Harmel
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 80/100: The Spanish Love Deception (Love Deception, #1) by Elena  Armas
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 81/100: Billy Summers by Stephen        King
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 82/100: The Henna Artist (The Jaipur Trilogy, #1) by Alka Joshi
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 83/100: The Guncle (The Guncle, #1) by Steven  Rowley
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 84/100: Long Bright River by Liz    Moore
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 85/100: The Splendid and the Vile: A Saga of Churchill, Family, and Defiance During the Blitz by Erik Larson
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 86/100: One Dark Window (The Shepherd King, #1) by Rachel Gillig
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 87/100: The Girl with the Louding Voice by Abi Daré
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 88/100: Take a Hint, Dani Brown (The Brown Sisters, #2) by Talia Hibbert
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 89/100: Felix Ever After by Kacen Callender
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 90/100: Clap When You Land by Elizabeth Acevedo
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 91/100: The Empire of Gold (The Daevabad Trilogy, #3) by S.A. Chakraborty
#   ✓ Found in Open Library
#   ⚠ Missing description
# Processing 92/100: Ring Shout by P. Djèlí Clark
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 93/100: The Book of Longings by Sue Monk Kidd
# Error searching Open Library for 'The Book of Longings': cannot access local variable 'result' where it is not associated with a value
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 94/100: The Dictionary of Lost Words by Pip Williams
#   ✗ Not found in Open Library
#   ⚠ Missing description
# Processing 95/100: A Kingdom of Flesh and Fire (Blood and Ash, #2) by Jennifer L. Armentrout
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 96/100: The City We Became (Great Cities, #1) by N.K. Jemisin
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 97/100: Dear Edward by Ann Napolitano
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 98/100: The Death of Vivek Oji by Akwaeke Emezi
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 99/100: Home Before Dark by Riley Sager
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
# Processing 100/100: The Mirror & the Light (Thomas Cromwell, #3) by Hilary Mantel
#   ✓ Found in Open Library
#     - Has description
#   ✓ Has description
#
# Summary for 2020s:
#   - Books with descriptions: 69/100
# ✓ CSV saved to Google Drive: /content/drive/MyDrive/new_book_data/books_data_2020.csv
#
# Data collection complete! Collected 100 books.
#
# Overall Statistics:
# - Books with descriptions: 69/100 (69.0%)
